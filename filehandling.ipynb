# %% [markdown]
# <a href="https://colab.research.google.com/github/Nidhipandey633/PythonProgram/blob/main/filehandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program for writing data into a file
# Opening file for write operation
filev = open("firstfile.txt", "w")

# Writing five sentences into the file
print("Enter any 5 sentences:")

for x in range(5):
    # Input of data from user
    sentence = input(f"Sentence {x+1}: ")

    # Writing sentence into the file
    # We add + "\n" to ensure each sentence starts on a new line
    filev.write(sentence + "\n")
    print("--------------------")

print("Data successfully written!")

# Closing the file
filev.close()

# %%
# to open file for read operation
filev = open("firstfile.txt","r")
# to check file is open or not
if(filev):
    # to read data from file
    data = filev.read()
    print(data)
    print("-------------")
    print("No. of characters : ",len(data))
    # closing file
    filev.close()
else:
    print("Unable to open the file")
