# %% [markdown]
# <a href="https://colab.research.google.com/github/Nidhipandey633/PythonProgram/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_even(number):
    if number % 2 == 0:
        return True
    else:
        return False

# Get input from the user

    num = int(input("Enter an integer: "))
    if is_even(num):
        print(f"{num} is an even number.")
    else:
        print(f"{num} is an odd number.")
